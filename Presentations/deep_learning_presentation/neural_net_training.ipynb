# %%
from pathlib import Path

dataset_dir = Path.home() / "Documents/kaggle-data/CelebFaces"
images_dir = dataset_dir / "img_align_celeba/img_align_celeba"
images = list(images_dir.glob("*.jpg"))

# %%
from PIL import Image

# Load the first jpg and display it
im = Image.open(images[0])
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=178x218>

# %%
import numpy as np

np.array(im).shape
# Out:
# (218, 178, 3)

# %%
import keras.layers as L
from keras import Model
